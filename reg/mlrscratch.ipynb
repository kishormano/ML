# %%
import pandas as pd

dt = pd.read_csv("Student_Performance.csv")

# %%
dt
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
print(dt.columns)
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
dt['Extracurricular Activities'] = dt['Extracurricular Activities'].map({"Yes":1, "No":0})
dt.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
x = dt[['Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced']].copy()
y = dt[['Performance Index']].copy()

x['int'] = 1

x = x[['int', 'Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced']]

x.head()
# Out:
#    int  Hours Studied  Previous Scores  Extracurricular Activities  \
# 0    1              7               99                           1
# 1    1              4               82                           0
# 2    1              8               51                           1
# 3    1              5               52                           1
# 4    1              7               75                           0
#
#    Sleep Hours  Sample Question Papers Practiced
# 0            9                                 1
# 1            4                                 2
# 2            7                                 2
# 3            5                                 2
# 4            8                                 5

# %%
import numpy as np
coeff = np.linalg.inv(x.T @ x) @ x.T @ y
coeff
# Out:
#    Performance Index
# 0         -34.075588
# 1           2.852982
# 2           1.018434
# 3           0.612898
# 4           0.480560
# 5           0.193802

# %%
coeff.index = x.columns
coeff
# Out:
#                                   Performance Index
# int                                      -34.075588
# Hours Studied                              2.852982
# Previous Scores                            1.018434
# Extracurricular Activities                 0.612898
# Sleep Hours                                0.480560
# Sample Question Papers Practiced           0.193802

# %%
pred = x @ coeff
pred
# Out:
#       Performance Index
# 0             91.852009
# 1             63.157787
# 2             45.052832
# 3             36.551201
# 4             67.091339
# ...                 ...
# 9995          21.603410
# 9996          56.501461
# 9997          72.998729
# 9998          94.366183
# 9999          65.297697
#
# [10000 rows x 1 columns]

# %%
ssr = ((y - pred) ** 2).sum()
sst = ((y - y.mean()) ** 2).sum()

acc = (1 - (ssr/sst)) * 100

acc
# Out:
# Performance Index    98.875233
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

reg.fit(dt[['Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced']], dt[['Performance Index']])

# %%
reg.intercept_
# Out:
# array([-34.07558809])

# %%
reg.coef_
# Out:
# array([[2.85298205, 1.01843419, 0.61289758, 0.48055975, 0.19380214]])

# %%
coeff
# Out:
#                                   Performance Index
# int                                      -34.075588
# Hours Studied                              2.852982
# Previous Scores                            1.018434
# Extracurricular Activities                 0.612898
# Sleep Hours                                0.480560
# Sample Question Papers Practiced           0.193802
